# %%
# %load_ext sql

# %%
# %sql postgresql://joshbacher@127.0.0.1/hr_tech_abc

# %% [markdown]
# ### List of employees wth job titles & department names:

# %%
# %sql SELECT e.emp_name, j.job_title, d.dept_nm \
     FROM Employee e \
     JOIN Employment_History ehist \
     ON e.emp_id = ehist.emp_id \
     JOIN Job j \
     ON ehist.job_title_id = j.job_title_id \
     JOIN Department d \
     ON ehist.dept_id = d.dept_id \
     WHERE end_dt IS NULL;
# Out:
#  * postgresql://joshbacher@127.0.0.1/hr_tech_abc
# 198 rows affected.
# [('Walter Waddler', 'Design Engineer', 'Product Development'),
#  ('Alan Mecklet', 'Administrative Assistant', 'Product Development'),
#  ('Frank Debanco', 'Sales Rep', 'Product Development'),
#  ('Phil  Wisneski', 'Sales Rep', 'Product Development'),
#  ('Tuan Yang', 'Sales Rep', 'Product Development'),
#  ('Wilson Martinez', 'Sales Rep', 'Product Development'),
#  ('Erica Davis', 'Sales Rep', 'Product Development'),
#  ('Darshan Rathod', 'Sales Rep', 'Product Development'),
#  ('Justin Hayes', 'Sales Rep', 'Product Development'),
#  ('Travis Black', 'Sales Rep', 'Product Development'),
#  ('Kenneth Dewitt', 'Sales Rep', 'Product Development'),
#  ('Marie Dumadara', 'Sales Rep', 'Product Development'),
#  ('Bertin Dakouo', 'Sales Rep', 'Product Development'),
#  ('Sonali Baidya', 'Sales Rep', 'Product Development'),
#  ('Greg Stirton', 'Sales Rep', 'Product Development'),
#  ('Vivian Kovach', 'Sales Rep', 'Product Development'),
#  ('Nick Gowen', 'Sales Rep', 'Product Development'),
#  ('Cassidy Bancroft', 'Sales Rep', 'Product Development'),
#  ('Melissa DeMaio', 'Sales Rep', 'Product Development'),
#  ('Kyle Guilmartin', 'Sales Rep', 'Product Development'),
#  ('Roseann Martineeti', 'Sales Rep', 'Product Development'),
#  ('Doug Tomson', 'Sales Rep', 'Product Development'),
#  ('Curtis Gibson', 'Sales Rep', 'Product Development'),
#  ('Raisa Paulson', 'Software Engineer', 'Product Development'),
#  ('Jermaine Massey', 'Software Engineer', 'Product Development'),
#  ('Nital Thaker', 'Software Engineer', 'Product Development'),
#  ('Victoria Pruitt', 'Software Engineer', 'Product Development'),
#  ('Rachael Anderson', 'Software Engineer', 'Product Development'),
#  ('Anil Padala', 'Software Engineer', 'Product Development'),
#  ('Chandi Bhandari', 'Software Engineer', 'Product Development'),
#  ('Aaron Gordon ', 'Network Engineer', 'Product Development'),
#  ('Karen Brown', 'Network Engineer', 'Product Development'),
#  ('Janice Canterbury', 'Network Engineer', 'Product Development'),
#  ('Siena Spitzer', 'Network Engineer', 'Product Development'),
#  ('Brent Robinson', 'Design Engineer', 'Product Development'),
#  ('Hitesh Bhatt', 'Design Engineer', 'Product Development'),
#  ('Michael Tholstrup', 'Design Engineer', 'Product Development'),
#  ('Joey Fulkerson', 'Design Engineer', 'Product Development'),
#  ('Elaine Podwika', 'Design Engineer', 'Product Development'),
#  ('Fiona Morris', 'Design Engineer', 'Product Development'),
#  ('Tanya Maheshwari', 'Legal Counsel', 'Product Development'),
#  ('Mallory Russo', 'Legal Counsel', 'Product Development'),
#  ('Carlos Fernandes', 'Sales Rep', 'Product Development'),
#  ('James Henderson', 'Sales Rep', 'Product Development'),
#  ('Nathan Hile ', 'Sales Rep', 'Product Development'),
#  ('Jody Hopkins', 'Sales Rep', 'Product Development'),
#  ('Robert Brown', 'Software Engineer', 'Product Development'),
#  ('Arnold Hanson', 'Software Engineer', 'Product Development'),
#  ('Jennifer Westin', 'Software Engineer', 'Product Development'),
#  ('Ludovic Bocken', 'Software Engineer', 'Product Development'),
#  ('Ginger Logan', 'Network Engineer', 'Product Development'),
#  ('Dakeem Coleman', 'Network Engineer', 'Product Development'),
#  ('Shawn Reynolds', 'Design Engineer', 'Product Development'),
#  ('Darryl Reamer', 'Legal Counsel', 'Product Development'),
#  ('Keith Ingram', 'Administrative Assistant', 'Product Development'),
#  ('Krishna Burli', 'Administrative Assistant', 'Product Development'),
#  ('Jill Fram', 'Administrative Assistant', 'Product Development'),
#  ('Muhammed Rubel', 'Administrative Assistant', 'Product Development'),
#  ('Aaron Richman', 'Administrative Assistant', 'Product Development'),
#  ('Kathy Abiskaroon', 'Administrative Assistant', 'Product Development'),
#  ('Andrew Yoon', 'Sales Rep', 'Product Development'),
#  ('Yuesef Hosni', 'Sales Rep', 'Product Development'),
#  ('Johnathan Wayman', 'Sales Rep', 'Product Development'),
#  ('Laura House', 'Sales Rep', 'Product Development'),
#  ('Colleen Alma', 'Network Engineer', 'Product Development'),
#  ('Daniel Matkovic', 'Network Engineer', 'Product Development'),
#  ('Nicole Lee', 'Administrative Assistant', 'Product Development'),
#  ('Cheryl Pike', 'Administrative Assistant', 'Product Development'),
#  ('Conner Kinch', 'Manager', 'Product Development'),
#  ('Janice Mayzlik', 'Legal Counsel', 'HQ'),
#  ('Dennis Fredrich', 'Legal Counsel', 'HQ'),
#  ('Anu Patel', 'Legal Counsel', 'HQ'),
#  ('Tom Wilson', 'Legal Counsel', 'HQ'),
#  ('Zach Bratkovich', 'Legal Counsel', 'HQ'),
#  ('Stephen Colluci', 'Legal Counsel', 'HQ'),
#  ('John Certa', 'Administrative Assistant', 'HQ'),
#  ('Randy Myers', 'Administrative Assistant', 'HQ'),
#  ('Anita Deluise', 'Administrative Assistant', 'HQ'),
#  ('Danny Godiksen', 'Administrative Assistant', 'HQ'),
#  ('Raven Landis', 'Administrative Assistant', 'HQ'),
#  ('Joseph Donohue', 'Administrative Assistant', 'HQ'),
#  ('Susan Cole ', 'Shipping and Receiving', 'Distribution'),
#  ('Christina Roth', 'Shipping and Receiving', 'Distribution'),
#  ('Juan Cosme', 'Shipping and Receiving', 'Distribution'),
#  ('Cassidy Clayton', 'Legal Counsel', 'Distribution'),
#  ('Michael Scilla', 'Legal Counsel', 'Distribution'),
#  ('John Perez', 'Legal Counsel', 'Distribution'),
#  ('Alex Warring', 'Shipping and Receiving', 'Distribution'),
#  ('Leo Manhanga', 'Shipping and Receiving', 'Distribution'),
#  ('Courtney Newman', 'Shipping and Receiving', 'Distribution'),
#  ('Raymond Dorset', 'Shipping and Receiving', 'Distribution'),
#  ('Wendell Mobley', 'Administrative Assistant', 'Distribution'),
#  ('Jason Wingard', 'Administrative Assistant', 'Distribution'),
#  ('Nilden Tutalar', 'Shipping and Receiving', 'Distribution'),
#  ('Michelle Zietz', 'Shipping and Receiving', 'Distribution'),
#  ('Kelly Price', 'Shipping and Receiving', 'Distribution'),
#  ('Russell Morales', 'Shipping and Receiving', 'Distribution'),
#  ('Michael Sperduti', 'Administrative Assistant', 'Distribution'),
#  ('Kumar Durairaj', 'Shipping and Receiving', 'Distribution'),
#  ('Shanteel Jackson', 'Shipping and Receiving', 'Distribution'),
#  ('Prashant Sharma', 'Shipping and Receiving', 'Distribution'),
#  ('Stan Frank', 'Shipping and Receiving', 'Distribution'),
#  ('Haifa Hajiri', 'Administrative Assistant', 'Distribution'),
#  ('Ashley Bergman', 'Administrative Assistant', 'Distribution'),
#  ('Carlos Lopez', 'Administrative Assistant', 'Distribution'),
#  ('Allison Gentle', 'Manager', 'Distribution'),
#  ('Erica Siegal', 'Sales Rep', 'Sales'),
#  ('Misha Tsidulko', 'Sales Rep', 'Sales'),
#  ('Susan Woodruff', 'Sales Rep', 'Sales'),
#  ('Diana Teppen', 'Sales Rep', 'Sales'),
#  ('Grace Messinger', 'Sales Rep', 'Sales'),
#  ('Preston Lilly', 'Sales Rep', 'Sales'),
#  ('Analyn Braza', 'Sales Rep', 'Sales'),
#  ('Belinda Van Loon', 'Sales Rep', 'Sales'),
#  ('Greg Pratt', 'Sales Rep', 'Sales'),
#  ('Sharon Gillies', 'Sales Rep', 'Sales'),
#  ('Zoey Bulter', 'Sales Rep', 'Sales'),
#  ('Jen  Frangias', 'Sales Rep', 'Sales'),
#  ('Roseann Clemente', 'Sales Rep', 'Sales'),
#  ('Tyrone Curtis', 'Sales Rep', 'Sales'),
#  ('Charles Wirry', 'Sales Rep', 'Sales'),
#  ('Norman Guerrero', 'Sales Rep', 'Sales'),
#  ('Leobrian Mason', 'Sales Rep', 'Sales'),
#  ('Soek Sohn', 'Sales Rep', 'Sales'),
#  ('Wes Tappan', 'Sales Rep', 'Sales'),
#  ('Charles Barker', 'Sales Rep', 'Sales'),
#  ('Max Yish', 'Sales Rep', 'Sales'),
#  ('Yawer Ali', 'Sales Rep', 'Sales'),
#  ('Lena Thorton', 'Sales Rep', 'Sales'),
#  ('Patti Hoeg', 'Sales Rep', 'Sales'),
#  ('Sara Erwin', 'Sales Rep', 'Sales'),
#  ('Eileen Chuss', 'Sales Rep', 'Sales'),
#  ('Alejandro Scannapieco', 'Sales Rep', 'Sales'),
#  ('Tami Smith', 'Sales Rep', 'Sales'),
#  ('Becky Weaver', 'Sales Rep', 'Sales'),
#  ('Elliot Foley', 'Sales Rep', 'Sales'),
#  ('Curtis Steward', 'Sales Rep', 'Sales'),
#  ('Samantha Kramer', 'Sales Rep', 'Sales'),
#  ('Parker Williams', 'Sales Rep', 'Sales'),
#  ('Benyam Gizaw', 'Legal Counsel', 'Sales'),
#  ('Jesse Curiel', 'Legal Counsel', 'Sales'),
#  ('Tracy Emerson', 'Legal Counsel', 'Sales'),
#  ('Tony Hughes', 'Administrative Assistant', 'Sales'),
#  ('Amit Hardiya', 'Administrative Assistant', 'Sales'),
#  ('Jorge Moscoso', 'Administrative Assistant', 'Sales'),
#  ('Jennifer De La Garza', 'Manager', 'Sales'),
#  ('Arup Das', 'Software Engineer', 'IT'),
#  ('Michael Kapper', 'Software Engineer', 'IT'),
#  ('Abby Lockhart', 'Database Administrator', 'IT'),
#  ('Mark Fiore', 'Database Administrator', 'IT'),
#  ('Paulius Mikalainis', 'Database Administrator', 'IT'),
#  ('Toni Lembeck', 'Database Administrator', 'IT'),
#  ('Jeff Barnhill', 'Design Engineer', 'IT'),
#  ('Tom Meola', 'Design Engineer', 'IT'),
#  ('James Aryeetey', 'Design Engineer', 'IT'),
#  ('Kathy Fedder', 'Design Engineer', 'IT'),
#  ('William Graf', 'Administrative Assistant', 'IT'),
#  ('Congkhanh Nguyen', 'Software Engineer', 'IT'),
#  ('Tara Madison', 'Software Engineer', 'IT'),
#  ('Jamie Foskett', 'Software Engineer', 'IT'),
#  ('Melinda Fisher', 'Software Engineer', 'IT'),
#  ('Edward Eslser', 'Software Engineer', 'IT'),
#  ('Janice McQueen', 'Software Engineer', 'IT'),
#  ('Lu Huang', 'Software Engineer', 'IT'),
#  ('Ken Beer', 'Network Engineer', 'IT'),
#  ('Stacey Lewis', 'Network Engineer', 'IT'),
#  ('Barry Walsh', 'Network Engineer', 'IT'),
#  ('Angela Masdary', 'Network Engineer', 'IT'),
#  ('Kevin Soltis', 'Network Engineer', 'IT'),
#  ('Tim Lawler', 'Network Engineer', 'IT'),
#  ('Fausto Recalde', 'Network Engineer', 'IT'),
#  ('Holly Smith', 'Network Engineer', 'IT'),
#  ('Philip Barnett', 'Database Administrator', 'IT'),
#  ('Doris Venama', 'Database Administrator', 'IT'),
#  ('Thanuja Polani', 'Database Administrator', 'IT'),
#  ('Beth Sepkowski', 'Software Engineer', 'IT'),
#  ('Tammy Tieman', 'Software Engineer', 'IT'),
#  ('Dennis Wooten', 'Software Engineer', 'IT'),
#  ('Lori Scatchard', 'Software Engineer', 'IT'),
#  ('April Briggs', 'Software Engineer', 'IT'),
#  ('Geraldine Staler', 'Software Engineer', 'IT'),
#  ('Oliver Jia', 'Network Engineer', 'IT'),
#  ('Zondra Peck', 'Network Engineer', 'IT'),
#  ('Tiffany Harrington', 'Network Engineer', 'IT'),
#  ('Gary Boyd', 'Legal Counsel', 'IT'),
#  ('Cody Holland', 'Legal Counsel', 'IT'),
#  ('Faheem Ahmed', 'Legal Counsel', 'IT'),
#  ('Mary Wesson', 'Software Engineer', 'IT'),
#  ('Patricia DuBois', 'Software Engineer', 'IT'),
#  ('Danny Laxton', 'Administrative Assistant', 'IT'),
#  ('Eric  Baxter', 'Database Administrator', 'IT'),
#  ('Laura McKenna', 'Administrative Assistant', 'IT'),
#  ('Raj Prudvi', 'Administrative Assistant', 'IT'),
#  ('Karen Lafler', 'Network Engineer', 'IT'),
#  ('Micah Vass', 'Network Engineer', 'IT'),
#  ('Alexis Fitzpatrick', 'Administrative Assistant', 'IT'),
#  ('Ann Roberto', 'Administrative Assistant', 'IT'),
#  ('Jacob Lauber', 'Manager', 'IT')]

# %% [markdown]
# ### Number of Employees in each department:

# %%
# %sql SELECT d.dept_nm, COUNT(*) AS employee_count \
     FROM Employee e \
     JOIN Employment_History ehist \
     ON e.emp_id = ehist.emp_id \
     JOIN Department d \
     ON d.dept_id = ehist.dept_id \
     WHERE end_dt IS NULL \
     GROUP BY d.dept_nm;
# Out:
#  * postgresql://joshbacher@127.0.0.1/hr_tech_abc
# 5 rows affected.
# [('Product Development', 69),
#  ('HQ', 12),
#  ('Distribution', 25),
#  ('Sales', 40),
#  ('IT', 52)]

# %% [markdown]
# ### Current & past jobs for employee Toni Lembeck:
# (Including emp_name, job_title, dept, mngr_name, start & end_dt)

# %%
# %sql SELECT e.emp_name, j.job_title, d.dept_nm, m.manager, start_dt, end_dt \
     FROM Employee e \
     JOIN Employment_History ehist \
     ON e.emp_id = ehist.emp_id \
     JOIN Job j \
     ON ehist.job_title_id = j.job_title_id \
     JOIN Department d \
     ON ehist.dept_id = d.dept_id \
     JOIN Manager m \
     ON m.manager_id = ehist.manager_id \
     WHERE e.emp_name = 'Toni Lembeck';
# Out:
#  * postgresql://joshbacher@127.0.0.1/hr_tech_abc
# 2 rows affected.
# [('Toni Lembeck', 'Database Administrator', 'IT', 'Jacob Lauber', datetime.date(2001, 7, 18), None),
#  ('Toni Lembeck', 'Network Engineer', 'IT', 'Jacob Lauber', datetime.date(1995, 3, 12), datetime.date(2001, 7, 17))]
